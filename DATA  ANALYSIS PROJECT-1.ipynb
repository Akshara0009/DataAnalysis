# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\aksha\OneDrive\Documents\STATISTICS\Weather_Data.csv")

# %%
df.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.3              -3.5         18                9
# 1  01-01-2012 01:00     7.4               2.8         20               24
# 2  01-01-2012 02:00    15.7              13.4         21               26
# 3  01-01-2012 03:00     4.9              -2.6         27               15
# 4  01-01-2012 04:00   -13.4             -19.7         30                4
#
#    Visibility_km  Press_kPa        Weather
# 0           25.0      98.67          Clear
# 1           24.1      99.37           Rain
# 2           25.0      99.84         Cloudy
# 3           24.1     100.94   Mainly Clear
# 4           25.0     102.32  Mostly Cloudy

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# ### Q. 1) Find all the unique 'Wind Speed' values in the data.

# %%
df["Wind Speed_km/h"].nunique()
# Out:
# 34

# %%
df["Wind Speed_km/h"].unique()
# Out:
# array([ 9, 24, 26, 15,  4,  0, 19, 17, 11, 22, 35, 13, 20,  6,  7, 30, 32,
#        41, 39, 28, 44, 33, 37, 52, 46,  2, 50, 48, 57, 63, 43, 83, 70, 54],
#       dtype=int64)

# %% [markdown]
# ### Q. 2) Find the number of times when the 'Weather is exactly Clear'.

# %%
weather_count=df["Weather"].value_counts()["Clear"]
print(weather_count)
# Out:
# 1326

# %% [markdown]
#  ### Q. 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
windspeed_count=len(df[(df["Wind Speed_km/h"]==4)])
print(windspeed_count)
# Out:
# 474

# %% [markdown]
# ### Q. 4) Find out all the Null Values in the data.

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# ### Q. 5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.

# %%
df1=df.rename(columns={"Weather":"Weather Condition"})
df1
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.3              -3.5         18                9
# 1     01-01-2012 01:00     7.4               2.8         20               24
# 2     01-01-2012 02:00    15.7              13.4         21               26
# 3     01-01-2012 03:00     4.9              -2.6         27               15
# 4     01-01-2012 04:00   -13.4             -19.7         30                4
# ...                ...     ...               ...        ...              ...
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
# 8782    9/30/2012 8:00    -6.3             -13.5         99               15
# 8783    9/30/2012 9:00    24.5              14.7        100               11
#
# ...

# %% [markdown]
# ### Q. 6) What is the mean 'Visibility' ?

# %%
df["Visibility_km"].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# ###  Q. 7) What is the Standard Deviation of 'Pressure' in this data?

# %%
df["Press_kPa"].std()
# Out:
# 0.8440047459486459

# %% [markdown]
#  ### Q. 8) What is the Variance of 'Relative Humidity' in this data ?

# %%
df["Rel Hum_%"].var()
# Out:
# 286.2485501985015

# %% [markdown]
#  ### Q. 9) Find all instances when 'Snow' was recorded.

# %%
snow_count=df[df["Weather"]=="Snow"]
snow_count
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 11    01-01-2012 11:00    -6.2              -9.6         37               35
# 70    03-01-2012 22:00    -4.0              -6.6         62               22
# 73    04-01-2012 01:00     2.3              -3.4         64               35
# 105   05-01-2012 09:00    -1.8              -4.2         73               15
# 112   05-01-2012 16:00     1.7              -0.3         75                6
# ...                ...     ...               ...        ...              ...
# 8573   9/22/2012 13:00    -6.0             -10.2         82               19
# 8650   9/25/2012 18:00    -4.6              -6.6         52                4
# 8671   9/26/2012 15:00    -5.9             -10.5         60               13
# 8713    9/28/2012 1:00    -5.2              -7.8         72               33
# 8734    9/28/2012 8:00     0.7              -1.2         79               30
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
df3=df[["Weather"]][df['Weather']=='Snow']
df3
# Out:
#      Weather
# 11      Snow
# 70      Snow
# 73      Snow
# 105     Snow
# 112     Snow
# ...      ...
# 8573    Snow
# 8650    Snow
# 8671    Snow
# 8713    Snow
# 8734    Snow
#
# [390 rows x 1 columns]

# %% [markdown]
#  ### Q. 10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
df2=df[(df["Wind Speed_km/h"]>24) & (df["Visibility_km"]==25)]
df2
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 2     01-01-2012 02:00    15.7              13.4         21               26
# 73    04-01-2012 01:00     2.3              -3.4         64               35
# 126   06-01-2012 06:00    10.0               5.4         77               39
# 158   07-01-2012 14:00     1.9              -2.1         87               26
# 184   08-01-2012 16:00    14.2               9.2         35               44
# ...                ...     ...               ...        ...              ...
# 8707    9/27/2012 5:00    -1.0              -6.0         70               33
# 8714   9/28/2012 10:00     2.6               0.3         72               26
# 8738   9/29/2012 10:00    22.8              12.3         80               28
# 8745   9/29/2012 17:00   -10.3             -12.9         82               28
# 8776   9/30/2012 23:00    19.2              13.2         93               43
#
# ...

# %%
df3=df[["Wind Speed_km/h","Visibility_km"]][(df["Wind Speed_km/h"]>24) & (df["Visibility_km"]==25)]
df3
# Out:
#       Wind Speed_km/h  Visibility_km
# 2                  26           25.0
# 73                 35           25.0
# 126                39           25.0
# 158                26           25.0
# 184                44           25.0
# ...               ...            ...
# 8707               33           25.0
# 8714               26           25.0
# 8738               28           25.0
# 8745               28           25.0
# 8776               43           25.0
#
# [308 rows x 2 columns]

# %% [markdown]
# ### Q. 11) What is the Mean value of each column against each 'Weather Condition ?

# %%
df.mean(numeric_only=True)
# Out:
# Temp_C                8.798144
# Dew Point Temp_C      2.555294
# Rel Hum_%            67.431694
# Wind Speed_km/h      14.945469
# Visibility_km        27.664447
# Press_kPa           101.051623
# dtype: float64

# %% [markdown]
# ### Q. 12) What is the Minimum & Maximum value of each column against each 'Weather Condition ?

# %%
df.iloc[0:7].agg(["min","max"])
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# min  01-01-2012 00:00   -13.4             -19.7         18                0
# max  01-01-2012 06:00    15.7              13.4         30               26
#
#      Visibility_km  Press_kPa Weather
# min           24.1      98.50   Clear
# max           25.0     102.39    Rain

# %% [markdown]
# ### Q. 13) Show all the Records where Weather Condition is Fog.

# %%
fog=df[df["Weather"]=="Fog"]
fog
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 13    01-01-2012 13:00     9.5               7.8         40               13
# 53    03-01-2012 05:00    -3.6              -4.3         57                7
# 136   06-01-2012 16:00    14.8              13.5         80               19
# 197   09-01-2012 05:00     2.1               0.7         43               11
# 278   12-01-2012 14:00     1.2               0.6         70               13
# ...                ...     ...               ...        ...              ...
# 8475   9/18/2012 11:00     6.2               5.4         56                7
# 8511   9/19/2012 22:00    15.7              15.4         66                7
# 8518    9/19/2012 8:00    -2.9              -4.5         68                6
# 8537    9/20/2012 3:00    -0.5              -2.1         74                7
# 8771   9/30/2012 19:00    12.8              12.2         91               19
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
df4= df[["Weather"]][df["Weather"]=='Fog']
df4
# Out:
#      Weather
# 13       Fog
# 53       Fog
# 136      Fog
# 197      Fog
# 278      Fog
# ...      ...
# 8475     Fog
# 8511     Fog
# 8518     Fog
# 8537     Fog
# 8771     Fog
#
# [150 rows x 1 columns]

# %% [markdown]
# ### Q. 14) Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
## 14
df5=df[(df["Weather"] == 'Clear')|(df["Visibility_km"]>40)]
df5
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.3              -3.5         18                9
# 9     01-01-2012 09:00    20.0               3.8         35               17
# 16    01-01-2012 16:00    23.8              17.6         42                9
# 17    01-01-2012 17:00    -6.8              -9.8         42               20
# 18    01-01-2012 18:00     2.3              -2.4         42                6
# ...                ...     ...               ...        ...              ...
# 8774   9/30/2012 21:00    23.0              14.7         92               13
# 8777    9/30/2012 3:00     9.3               5.8         95                9
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
#
# ...

# %%
df6=df[["Weather",'Visibility_km']][(df["Weather"]== 'Clear') | (df["Visibility_km"] > 40)]
df6
# Out:
#             Weather  Visibility_km
# 0             Clear           25.0
# 9             Clear           48.3
# 16            Clear           25.0
# 17     Mainly Clear           48.3
# 18           Cloudy           48.3
# ...             ...            ...
# 8774  Mostly Cloudy           48.3
# 8777   Mainly Clear           48.3
# 8779         Cloudy           48.3
# 8780  Mostly Cloudy           48.3
# 8781          Clear           24.1
#
# [3027 rows x 2 columns]

# %% [markdown]
# ### Q. 15) Find all instances when :
# #### A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# #### or
# #### B. 'Visibility is above 40'

# %%
df7=df[((df["Weather"]=="Clear")& (df["Rel Hum_%"]>50))|(df["Visibility_km"]>40)]
df7
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 9     01-01-2012 09:00    20.0               3.8         35               17
# 17    01-01-2012 17:00    -6.8              -9.8         42               20
# 18    01-01-2012 18:00     2.3              -2.4         42                6
# 19    01-01-2012 19:00   -12.7             -17.2         43               17
# 23    01-01-2012 23:00    29.5              16.8         45                4
# ...                ...     ...               ...        ...              ...
# 8774   9/30/2012 21:00    23.0              14.7         92               13
# 8777    9/30/2012 3:00     9.3               5.8         95                9
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
#
# ...

# %%
df8=df[["Weather",'Rel Hum_%','Visibility_km']][(df["Weather"] == 'Clear') & (df["Rel Hum_%"] > 50) | (df['Visibility_km'] > 40)]
df8
# Out:
#             Weather  Rel Hum_%  Visibility_km
# 9             Clear         35           48.3
# 17     Mainly Clear         42           48.3
# 18           Cloudy         42           48.3
# 19            Clear         43           48.3
# 23     Mainly Clear         45           48.3
# ...             ...        ...            ...
# 8774  Mostly Cloudy         92           48.3
# 8777   Mainly Clear         95           48.3
# 8779         Cloudy         97           48.3
# 8780  Mostly Cloudy         98           48.3
# 8781          Clear         99           24.1
#
# [2864 rows x 3 columns]
